# %%
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df = pd.read_excel("zomato_data.xlsx")

# %%
df.head()
# Out:
#    Order ID  Order Amount (INR)  Delivery Time (mins) Order Date  Rating  \
# 0         1                1930                    32 2023-04-30     4.6
# 1         2                 371                    84 2023-01-06     2.7
# 2         3                1389                    82 2024-02-18     3.9
# 3         4                 329                    50 2023-07-06     1.9
# 4         5                 400                    19 2024-06-21     3.4
#
#    Number of Items  Delivery Distance (km)  Delivery Agent ID Order Status  \
# 0                9                9.200017                995    Cancelled
# 1                1                8.175074                941    Cancelled
# 2                5               13.280443                469    Delivered
# 3                1               11.892893                329   In-Transit
# 4                4                2.570476                172    Cancelled
#
#   Payment Method  ...  average_cost_for_two price_range  \
# ...

# %%
# Q1. How many total rows and columns are there in the dataset?
df.shape
# Out:
# (12079, 33)

# %%
#Q2. What are the names of all the columns in the dataset?
df.columns.tolist()
# Out:
# ['Order ID',
#  'Order Amount (INR)',
#  'Delivery Time (mins)',
#  'Order Date',
#  'Rating',
#  'Number of Items',
#  'Delivery Distance (km)',
#  'Delivery Agent ID',
#  'Order Status',
#  'Payment Method',
#  'Tip Amount (INR)',
#  'Promo Code Applied',
#  'Has Free Delivery',
#  'res_id',
#  'name',
#  'type',
#  'address',
#  'city',
#  'locality',
#  'latitude',
#  'longitude',
#  'cuisines',
#  'timings',
#  'average_cost_for_two',
#  'price_range',
#  'highlights',
#  'aggregate_rating',
#  'votes',
#  'photo_count',
#  'opentable_support',
#  'delivery',
#  'state',
#  'area']

# %%
#Q3. What is the data type of each column?
df.dtypes
# Out:
# Order ID                           int64
# Order Amount (INR)                 int64
# Delivery Time (mins)               int64
# Order Date                datetime64[us]
# Rating                           float64
# Number of Items                    int64
# Delivery Distance (km)           float64
# Delivery Agent ID                  int64
# Order Status                         str
# Payment Method                       str
# Tip Amount (INR)                   int64
# Promo Code Applied                   str
# Has Free Delivery                    str
# res_id                             int64
# name                                 str
# type                                 str
# address                              str
# city                                 str
# locality                             str
# latitude                         float64
# longitude                        float64
# cuisines                             str
# timings                              str
# ...

# %%
df.select_dtypes(include=['number']).columns
df.select_dtypes(include=['object','category']).columns
# Out:
# /var/folders/dq/q7st889528v76ffzrt2fk2_m0000gn/T/ipykernel_2790/15109061.py:2: Pandas4Warning: For backward compatibility, 'str' dtypes are included by select_dtypes when 'object' dtype is specified. This behavior is deprecated and will be removed in a future version. Explicitly pass 'str' to `include` to select them, or to `exclude` to remove them and silence this warning.
# See https://pandas.pydata.org/docs/user_guide/migration-3-strings.html#string-migration-select-dtypes for details on how to write code that works with pandas 2 and 3.
#   df.select_dtypes(include=['object','category']).columns
# Index(['Order Status', 'Payment Method', 'Promo Code Applied',
#        'Has Free Delivery', 'name', 'type', 'address', 'city', 'locality',
#        'cuisines', 'timings', 'highlights', 'state'],
#       dtype='str')

# %%
#Q5. How many missing values are there in each column?
df.duplicated().sum()
# Out:
# np.int64(212)

# %%
#Q6. Are there any duplicate rows in the dataset? If yes, how many?
df.duplicated().sum()
# Out:
# np.int64(212)

# %%
#Q7. Find the mean, minimum, maximum, and standard deviation of the numerical columns.
df.select_dtypes(include=['number']).agg(['mean','min','max','std'])
# Out:
#           Order ID  Order Amount (INR)  Delivery Time (mins)    Rating  \
# mean   5018.228165         1579.123355             49.578359  3.004330
# min       1.000000          150.000000             10.000000  1.000000
# max   10000.000000         2999.000000             89.000000  5.000000
# std    2883.136265          825.658629             23.196654  1.160856
#
#       Number of Items  Delivery Distance (km)  Delivery Agent ID  \
# mean         5.016392                7.653219         546.783012
# min          1.000000                0.500953         100.000000
# max          9.000000               14.999011         998.000000
# std          2.593551                4.207720         260.996003
#
#       Tip Amount (INR)        res_id   latitude  longitude  \
# mean         99.022104  1.275457e+07  21.314166  76.409870
# min           0.000000  8.900000e+01   0.000000   0.000000
# max         199.000000  1.915932e+07  34.084125  91.829984
# ...

# %%
df.columns['']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 df.dtype('order_date')
#
# File /Library/Frameworks/Python.framework/Versions/3.14/lib/python3.14/site-packages/pandas/core/generic.py:6194, in NDFrame.__getattr__(self, name)
#    6190             and name not in self._accessors
#    6191             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6192         ):
#    6193             return self[name]
# -> 6194         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'
